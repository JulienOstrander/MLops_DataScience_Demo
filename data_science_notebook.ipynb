# %% [markdown]
# <a href="https://colab.research.google.com/github/JulienOstrander/MLops_DataScience_Demo/blob/main/data_science_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Ingest

# %% [markdown]
# COVID 19 Data from New York Times Github

# %%
# @title
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %% [markdown]
# ##EDA

# %% [markdown]
# ##Modeling

# %% [markdown]
# ##Conclusion
